# %% [markdown]
# # Function definitions and loading files

# %%
from utils_plot import *

# %%
btc_to_usd_in_2020_11_24 = 18875.10

# %% [markdown]
# ## Load txs acceleration price data

# %%
tx_acceleration_df = pd.read_csv('data/tx_acceleration_prices_2020-11-24 10:08:41.932872.tsv.gz', sep=';')
tx_acceleration_df.rename(columns={'size': 'ssize'}, inplace=True)

# %%
tx_acceleration_df['final_price_usd'] = tx_acceleration_df['price_usd'] - tx_acceleration_df['discount_usd']

# %%
tx_acceleration_df.shape
# Out:
# (23341, 9)

# %%
tx_acceleration_df.head()
# Out:
#                                                                txid  ssize  \
# 0  052a65b28e88ce031804f88cf5eff66e07ceb37dc7419b3eff98fcb35b3fa274    482
# 1  bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f    214
# 2  630b1fc5e6055ee245ea2de8066d83510fc17a700eddd0b7c8ac10fc0c566504    224
# 3  d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece   1513
# 4  c60bdb95afa8674f6474c1b703e06448c02fc67d6f7e5b58dc2896bf61fd28a8    225
#
#    children_total_size  \
# 0                  450
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#
#                                                                                                                                                                                          flatten_tree  \
# 0  897a5a82f1b8d24041550834f61894ab0b8ff6a4af0bc4d71a1a04cacc31b42c,a7949253e803b51f61282cb68c4efb03bdf8929bba4a467effc84841f0fde3d9,052a65b28e88ce031804f88cf5eff66e07ceb37dc7419b3eff98fcb35b3fa274
# 1                                                                                                                                    bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f
# 2                                                                                                                                    630b1fc5e6055ee245ea2de8066d83510fc17a700eddd0b7c8ac10fc0c566504
# 3                                                                                                                                    d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece
# 4                                                                                                                                    c60bdb95afa8674f6474c1b703e06448c02fc67d6f7e5b58dc2896bf61fd28a8
#
#    price_usd  discount_usd  price_cny  discount_cny  final_price_usd
# 0     173.31         26.13    1139.53        171.85           147.18
# 1      39.79          0.93     261.62          6.16            38.86
# 2      41.65          1.12     273.85          7.38            40.53
# 3     281.35         58.54    1849.90        384.97           222.81
# 4      41.84          1.14     275.10          7.50            40.70

# %%
tx_acceleration_df.final_price_usd.describe()
# Out:
# count    23341.00000000
# mean       199.72862988
# std        744.65238365
# min         34.34000000
# 25%         40.70000000
# 50%         64.97000000
# 75%        120.59000000
# max      20969.86000000
# Name: final_price_usd, dtype: float64

# %% [markdown]
# ## Load mempool data
#
# #### 1 BTC worths 18,875.10 USD on November 24th, 2020

# %%
mempool_df = pd.read_csv('data/mempool_df_2020-11-24 10:08:41.932872.tsv.gz', sep=';')
mempool_df.rename(columns={'size': 'vsize'}, inplace=True)

# %%
mempool_df['fee_usd'] = (mempool_df['fee'] * btc_to_usd_in_2020_11_24).round(2)

# %%
mempool_df.shape
# Out:
# (26332, 17)

# %%
mempool_df.head()
# Out:
#                                                                txid  \
# 0  379299a2da48278667039202266ad90a35c901bd8e9bbc86f7a284c8da56fe04
# 1  a5983f469cdbbc3e1357ea2122daf20a3bbc64eee3cabad5ddccefd33c432b7a
# 2  b3e83576397e19657c8eab6dd5dc0238006e5e046d4fd27d7df1e04be7fa7fc6
# 3  a7c3de64c7e6337343051e96e608e7d62ffd47571bb499a8460bfcb7b3a28a8d
# 4  d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece
#
#                                                                                              fees  \
# 0        {'base': 4.54e-05, 'modified': 4.54e-05, 'ancestor': 5.86e-05, 'descendant': 0.00012882}
# 1                              {'base': 0.0, 'modified': 0.0, 'ancestor': 0.0, 'descendant': 0.0}
# 2      {'base': 4.096e-05, 'modified': 4.096e-05, 'ancestor': 4.096e-05, 'descendant': 4.096e-05}
# 3                              {'base': 0.0, 'modified': 0.0, 'ancestor': 0.0, 'descendant': 0.0}
# 4  {'base': 0.00019884, 'modified': 0.00019884, 'ancestor': 0.00019884, 'descendant': 0.00019884}
#
#    vsize         fee  modifiedfee                 time  height  \
# 0    224  0.00004540   0.00004540  2020-11-24 08:42:06  658433
# 1    340  0.00000000   0.00000000  2020-11-10 11:51:32  656288
# 2    271  0.00004096   0.00004096  2020-11-24 08:11:05  658432
# 3    340  0.00000000   0.00000000  2020-11-10 11:51:32  656288
# 4   1513  0.00019884   0.00019884  2020-11-24 09:20:07  658436
#
#    descendantcount  descendantsize  descendantfees  ancestorcount  \
# 0                2             414           12882              2
# 1                1             340               0              1
# 2                1             271            4096              1
# 3                1             340               0              1
# 4                1            1513           19884              1
#
#    ancestorsize  ancestorfees  \
# 0           450          5860
# 1           340             0
# 2           271          4096
# 3           340             0
# 4          1513         19884
#
#                                                               wtxid  \
# 0  379299a2da48278667039202266ad90a35c901bd8e9bbc86f7a284c8da56fe04
# 1  a5983f469cdbbc3e1357ea2122daf20a3bbc64eee3cabad5ddccefd33c432b7a
# 2  b3e83576397e19657c8eab6dd5dc0238006e5e046d4fd27d7df1e04be7fa7fc6
# 3  a7c3de64c7e6337343051e96e608e7d62ffd47571bb499a8460bfcb7b3a28a8d
# 4  d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece
#
#                                                                 depends  \
# 0  ['41fb690ea461eb90b6dd5dbdf25eaa538fa1e7e9e285ed1ca6bbbe520a0614d0']
# 1                                                                    []
# 2                                                                    []
# 3                                                                    []
# 4                                                                    []
#
#                                                                 spentby  \
# 0  ['978b3d96dca544516bbc93b5d44bddf1b81315fc7b0e6e6a1e7e53555b835512']
# 1                                                                    []
# 2                                                                    []
# 3                                                                    []
# 4                                                                    []
#
#    fee_usd
# 0     0.86
# 1     0.00
# 2     0.77
# 3     0.00
# 4     3.75

# %%
mempool_df[['fee', 'fee_usd']].describe()
# Out:
#                   fee         fee_usd
# count  26332.00000000  26332.00000000
# mean       0.00010557      1.99282394
# std        0.00068095     12.85300172
# min        0.00000000      0.00000000
# 25%        0.00001135      0.21000000
# 50%        0.00003842      0.73000000
# 75%        0.00008160      1.54000000
# max        0.06040421   1140.14000000

# %% [markdown]
# # Analysis

# %%
tx_acceleration_df.columns
# Out:
# Index(['txid', 'ssize', 'children_total_size', 'flatten_tree', 'price_usd',
#        'discount_usd', 'price_cny', 'discount_cny', 'final_price_usd'],
#       dtype='object')

# %%
mempool_df.columns
# Out:
# Index(['txid', 'fees', 'vsize', 'fee', 'modifiedfee', 'time', 'height',
#        'descendantcount', 'descendantsize', 'descendantfees', 'ancestorcount',
#        'ancestorsize', 'ancestorfees', 'wtxid', 'depends', 'spentby',
#        'fee_usd'],
#       dtype='object')

# %%
mempool_df.query('txid == "bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f"')
# Out:
#                                                                 txid  \
# 29  bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f
#
#                                                                                       fees  \
# 29  {'base': 9.38e-06, 'modified': 9.38e-06, 'ancestor': 9.38e-06, 'descendant': 9.38e-06}
#
#     vsize         fee  modifiedfee                 time  height  \
# 29    133  0.00000938   0.00000938  2020-11-23 19:48:22  658365
#
#     descendantcount  descendantsize  descendantfees  ancestorcount  \
# 29                1             133             938              1
#
#     ancestorsize  ancestorfees  \
# 29           133           938
#
#                                                                wtxid depends  \
# 29  bd3ce42f9011ca0b74be2de78f744360898bc2dc729b157731ede3b3c75289eb      []
#
#    spentby  fee_usd
# 29      []     0.18

# %%
tx_acceleration_df.query('txid == "bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f"')
# Out:
#                                                                txid  ssize  \
# 1  bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f    214
#
#    children_total_size  \
# 1                    0
#
#                                                        flatten_tree  \
# 1  bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f
#
#    price_usd  discount_usd  price_cny  discount_cny  final_price_usd
# 1      39.79          0.93     261.62          6.16            38.86

# %%
df = mempool_df.merge(tx_acceleration_df, right_on='txid', left_on='txid', how='right')
df['children_vsize'] = df['ancestorsize'] - df['vsize']

# %%
df.shape
# Out:
# (23341, 26)

# %%
df.head()
# Out:
#                                                                txid  \
# 0  052a65b28e88ce031804f88cf5eff66e07ceb37dc7419b3eff98fcb35b3fa274
# 1  bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f
# 2  630b1fc5e6055ee245ea2de8066d83510fc17a700eddd0b7c8ac10fc0c566504
# 3  d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece
# 4  c60bdb95afa8674f6474c1b703e06448c02fc67d6f7e5b58dc2896bf61fd28a8
#
#                                                                                              fees  \
# 0  {'base': 0.00020131, 'modified': 0.00020131, 'ancestor': 0.00024651, 'descendant': 0.00020131}
# 1          {'base': 9.38e-06, 'modified': 9.38e-06, 'ancestor': 9.38e-06, 'descendant': 9.38e-06}
# 2       {'base': 3.088e-05, 'modified': 3.088e-05, 'ancestor': 3.088e-05, 'descendant': 8.56e-05}
# 3  {'base': 0.00019884, 'modified': 0.00019884, 'ancestor': 0.00019884, 'descendant': 0.00019884}
# 4      {'base': 2.497e-05, 'modified': 2.497e-05, 'ancestor': 2.497e-05, 'descendant': 2.497e-05}
#
#    vsize         fee  modifiedfee                 time  height  \
# 0    482  0.00020131   0.00020131  2020-11-24 09:39:00  658436
# 1    133  0.00000938   0.00000938  2020-11-23 19:48:22  658365
# 2    224  0.00003088   0.00003088  2020-11-24 08:16:15  658433
# 3   1513  0.00019884   0.00019884  2020-11-24 09:20:07  658436
# 4    225  0.00002497   0.00002497  2020-11-24 07:52:16  658431
#
#    descendantcount  descendantsize  descendantfees  ...  fee_usd  ssize  \
# 0                1             482           20131  ...     3.80    482
# 1                1             133             938  ...     0.18    214
# 2                2             563            8560  ...     0.58    224
# 3                1            1513           19884  ...     3.75   1513
# 4                1             225            2497  ...     0.47    225
#
#    children_total_size  \
# 0                  450
# 1                    0
# 2                    0
# 3                    0
# 4                    0
#
#                                                                                                                                                                                          flatten_tree  \
# 0  897a5a82f1b8d24041550834f61894ab0b8ff6a4af0bc4d71a1a04cacc31b42c,a7949253e803b51f61282cb68c4efb03bdf8929bba4a467effc84841f0fde3d9,052a65b28e88ce031804f88cf5eff66e07ceb37dc7419b3eff98fcb35b3fa274
# 1                                                                                                                                    bfdd6ac8b5caa111c646d6d398c9109a65e6c92ff19f73734ea7f396284f5e6f
# 2                                                                                                                                    630b1fc5e6055ee245ea2de8066d83510fc17a700eddd0b7c8ac10fc0c566504
# 3                                                                                                                                    d91f953df0022b43a630263fe58d5db3e1a4dfcd510bd3e6bf4cfb69cf4ccece
# 4                                                                                                                                    c60bdb95afa8674f6474c1b703e06448c02fc67d6f7e5b58dc2896bf61fd28a8
#
#   price_usd discount_usd  price_cny  discount_cny  final_price_usd  \
# 0    173.31        26.13    1139.53        171.85           147.18
# 1     39.79         0.93     261.62          6.16            38.86
# 2     41.65         1.12     273.85          7.38            40.53
# 3    281.35        58.54    1849.90        384.97           222.81
# 4     41.84         1.14     275.10          7.50            40.70
#
#   children_vsize
# 0            450
# 1              0
# 2              0
# 3              0
# 4              0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Transaction fee vs acceleration price

# %%
ax = plot_cdf(data=mempool_df.query('txid in @tx_acceleration_df.txid').fee_usd, x_label='Transaction fee price (in usd)', y_label='CDF', log=True, interval=None,
             color=None, ax=None, label='transaction fee',
             linewidth=None, style='--', alpha=1, y_lim=[0, 1], marker=None, markersize=None)
ax = plot_cdf(data=tx_acceleration_df.final_price_usd, x_label='Transaction fee price (in usd)', y_label='CDF', log=True, interval=None,
             color=None, ax=ax, label='acceleration fee',
             linewidth=None, style='-', alpha=1, y_lim=[0, 1], marker=None, markersize=None)
ax.yaxis.set_minor_locator(ticker.MultipleLocator(.1))
plt.grid(which='minor', axis='both', linestyle=':')
plt.legend()
plt.savefig(f"plots/fees-cdf.pdf", bbox_inches='tight')

# %%
(100*(df['fee_usd']/df['final_price_usd']).describe()).round(2)
# Out:
# count    2334100.00
# mean           1.25
# std            1.80
# min            0.00
# 25%            0.28
# 50%            0.86
# 75%            1.94
# max          182.94
# dtype: float64

# %%
(df['final_price_usd']/df['fee_usd']).describe()
# Out:
# count     23341.00000000
# mean        566.29502157
# std        4734.67428849
# min           0.54661280
# 25%          51.63546798
# 50%         116.63900415
# 75%         351.80000000
# max      428800.00000000
# dtype: float64

# %%
data = df[
    ['fee_usd', 'final_price_usd', 'vsize', 'ssize', 'children_total_size', 'ancestorsize']
].describe().round(2)
data.describe()
# Out:
#               fee_usd  final_price_usd           vsize            ssize  \
# count      8.00000000       8.00000000      8.00000000       8.00000000
# mean    3062.09000000    5689.48000000  16054.21250000   32013.62625000
# std     8203.58092017   10185.36655155  34669.62828753   78156.40005491
# min        0.02000000      34.34000000    110.00000000     187.00000000
# 25%        0.55500000      58.90250000    216.75000000     240.50000000
# 50%        1.52500000     160.16000000    589.90500000     739.96000000
# 75%      293.75750000    5800.95250000   8691.91750000   10478.56750000
# max    23341.00000000   23341.00000000  99577.00000000  224440.00000000
#
#        children_total_size    ancestorsize
# count           8.00000000      8.00000000
# mean        29763.76000000  16272.16125000
# std         73013.10715173  34572.98926534
# min             0.00000000    110.00000000
# 25%             0.00000000    249.00000000
# 50%           307.96000000    949.35000000
# 75%          9423.37000000   9416.19250000
# max        209369.00000000  99577.00000000

# %%
sns.heatmap(
    df[['fee_usd', 'final_price_usd', 'vsize', 'ssize', 'descendantsize', 
        'ancestorsize', 'children_total_size', 'children_vsize']].corr(), 
    annot=True, cmap='Blues', cbar=True, linewidths=.5, annot_kws={"size": 14},
    fmt='.2f'
)
plt.savefig(f"plots/fees-corr-heatmap.pdf", bbox_inches='tight')

# %%
df.sort_values(
    by=['ancestorsize', 'final_price_usd', 'ssize', 'vsize', 'final_price_usd']
)[
    ['txid', 'final_price_usd', 'fee_usd', 'ancestorsize', 'ssize', 'vsize',
     'descendantsize', 'fee', 'time', 'height']].head(10)
# Out:
#                                                                   txid  \
# 43    c95c7d6de83b8c918fe9dc146a9d7f311338d42e593097de1bbcd12e0eef91d5
# 173   d22044704f09f478bf3fbff8ab47493e06feb385a8a610111b426e29808f3344
# 339   e267a47a38897b2a7a8ca054ce38c437f02b0c12038e5b0e19e2c0d37cbb6796
# 383   d4b48ba264f42178dc82c1f6134b78688740d2021b26da735fe758d80041001f
# 1148  f30bfc8c789775b42c56575eba1277ab7d4ed501c27f564eec39b8ae1c077f30
# 1518  dfe1a5dbd74938fb7a1746dc1677a79d93cbf0d4ec180b68aed7f66201b473cf
# 1522  a2a6799a763a514b7ef92a6d4676ae7cd08072d759f754a8d7c185c353fdce5a
# 1623  34fbfc93045b9d96f1c025b79c70f6a11782f6d0d6f28c859d9e2d8f8fe770ec
# 1958  fdb39f9cbc9a7cb86444900e43575717fbc5b96d0a7ce97ad2fe6555080381f3
# 2058  f3f63aa781b62c222aaad0cc65204f4ef3e8f8a63815480458774cd1b7bd45dc
#
#       final_price_usd  fee_usd  ancestorsize  ssize  vsize  descendantsize  \
# 43              35.01     0.02           110    191    110             110
# 173             35.01     0.07           110    191    110             492
# 339             35.01     0.07           110    191    110             110
# 383             35.01     0.02           110    191    110             110
# 1148            35.01     0.25           110    191    110             110
# 1518            35.01     0.21           110    191    110             110
# 1522            35.01     0.27           110    191    110             110
# 1623            35.01     0.08           110    191    110             110
# 1958            35.01     0.02           110    191    110             110
# 2058            35.01     0.12           110    191    110             110
#
#              fee                 time  height
# 43    0.00000110  2020-11-23 11:15:58  658312
# 173   0.00000387  2020-11-23 11:00:21  658312
# 339   0.00000363  2020-11-23 13:29:13  658326
# 383   0.00000110  2020-11-23 11:21:17  658312
# 1148  0.00001320  2020-11-24 02:27:37  658400
# 1518  0.00001100  2020-11-23 14:14:38  658332
# 1522  0.00001430  2020-11-23 10:57:49  658312
# 1623  0.00000440  2020-11-23 10:58:38  658312
# 1958  0.00000110  2020-11-23 11:18:36  658312
# 2058  0.00000660  2020-11-23 11:01:55  658312

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Preparing data set

# %%
features = ['fee', 'vsize', 'ssize', 'children_vsize', 'ancestorsize', 'children_total_size']
target = 'final_price_usd'

# %%
data = df[features+[target]]
data.shape
# Out:
# (23341, 7)

# %%
train_df, test_df = train_test_split(data, test_size=0.2, shuffle=True)
print(f"train={train_df.shape[0]}, test={test_df.shape[0]}")
# Out:
# train=18672, test=4669

# %% [markdown]
# ## Model

# %%
reg = LinearRegression(n_jobs=-1)

# %%
reg.fit(X=train_df[features], y=train_df[target])
# Out:
# LinearRegression(n_jobs=-1)

# %% [markdown]
# ## Evaluation

# %%
# Coefficients
print(f"Coefficients\n{dict(zip(features, reg.coef_))}")

# Intercept
print(f"\nIntercept={reg.intercept_}")
# Out:
# Coefficients
# {'fee': 1565.4064341539597, 'vsize': -0.0011517542894431976, 'ssize': 0.09195994136666333, 'children_vsize': 0.006144701756084962, 'ancestorsize': 0.0049908054200825, 'children_total_size': 0.08801259125329351}
#
# Intercept=36.553002259882675

# %%
pred = reg.predict(test_df[features])
mean_error = mean_squared_error(test_df[target], pred)
coef_determination = r2_score(test_df[target], pred)

# %%
print('Mean squared error: %.2f'% mean_error)
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'% coef_determination)
# Out:
# Mean squared error: 581.13
# Coefficient of determination: 1.00

# %%
# Plot outputs
fig, ax = plt.subplots()
ax.scatter(test_df[target], pred)

# plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)
ax.set_xlabel('Actual')
ax.set_ylabel('Predicted')

props = dict(boxstyle='round', facecolor='white', alpha=0.5)
ax.text(0.55, 0.2, 'Mean squared error: %.2f\nCoefficient of determination: %.2f'% 
        (mean_error, coef_determination), transform=ax.transAxes, fontsize=15,
        verticalalignment='top', bbox=props)

ax.set_xlim((0, 20030))
ax.set_ylim((0, 20000))

plt.savefig(f"plots/fees-prediction-scatter.pdf", bbox_inches='tight')

# %%
test = df[['txid', 'final_price_usd', 'children_vsize', 'children_total_size', 'vsize', 'ssize']].query('children_vsize > 0')

# %%
test.query('children_vsize != children_total_size')
# Out:
#                                                                    txid  \
# 21     1cb1f3c0f574e5c2641b44483f64d7aefe65bf4bf0fa0676280a73c96134fbd4
# 26     bb286f3589126093b2327bb08f699c16bd50995253748f7756a47070e51b4a4d
# 33     5e487e82ae7b5a17e335a377dda13b39bbbe87a2f1ce2805f10175e78061f981
# 41     0a7d7f472cf7d5bc40411c289d0bfea45d7a2e4b93c5c6bc6c4deacbafa5a7c8
# 48     2f9bb32253656b4941a93de5f8166b7a9c0d1678f8fb7d8e9e53347b89181738
# ...                                                                 ...
# 23299  36e221491a970d422d4ddf1452fe43ce42b7e5b29f4923d403c32cc910f1f624
# 23310  2a613935a525cb912b2b435aa4a60652148408bd0192c89bbc2edf7566a9766b
# 23318  c950b73dbdcb79f1049eeed3e2cdac088845d282e2bc4493c55f6de4930296d1
# 23327  783c702a6ced625d4191284075e013bb2114f96803879ca508839ad9b9b45267
# 23333  87bbca34865d3a2ab589b7337d410a4780dbabf3868d0fd991d41b38e1f99afc
#
#        final_price_usd  children_vsize  children_total_size  vsize  ssize
# 21               84.14             166                  247    166    247
# 26              281.54            1148                 1796    142    223
# 33              144.05             168                  249    417    659
# 41              681.53            4241                 5951    202    283
# 48              215.90             794                 1041    257    419
# ...                ...             ...                  ...    ...    ...
# 23299           120.88             206                  371    205    370
# 23310           471.68            2317                 3604    373    373
# 23318           868.97            7456                 8024    226    226
# 23327            77.29             144                  225    223    223
# 23333           889.99            7682                 8250    226    226
#
# [2028 rows x 6 columns]

# %%
df.query('ancestorcount == 1')[['txid', 'final_price_usd', 'fee_usd', 'vsize', 'ssize']].sort_values(
by=['final_price_usd', 'ssize'])
# Out:
#                                                                    txid  \
# 5308   fd3a6b56c01c124d8702a074c398148a44aa413d056b1f64e4145526bc419bfa
# 12710  dc9776b2b9279068932e2fd0a1dde16ea1c0075bdae52ca9ace1561144755b7f
# 538    e3698da33130831aa2db6f314322bf5e200d3ea1de3357544ce8738e865273d9
# 561    39eecaedf70ee08b6af140c4bd04f3fc5b7bb1fa8ad13e29d8aaf0fde3591d4b
# 1176   52dd8140c2c13c65857bc7f508923462c334a1d51299b0e0d84d220a2384bdb2
# ...                                                                 ...
# 5300   ca8b74c8dff8923b116f781d35282221318c650ee4dcc2f2ab5844a51d333c9a
# 13011  70795a99cd7c98665a2ab75881c66b5c4ea9e2bbad3de71011726fbcd4cff8a8
# 13250  d9d1abdd1438ab4a5185b93b66c3d408c9c9a6e7d0b7fea2d1ef7627dfe37f10
# 4399   d577c6e2cf86550affbfec5052c2693b9ef5f02fcc886638016649e2e58065fc
# 11387  a5a654cba867f54451aeec44d0a48eb82fe860a30c12a6ca344deccc5713963c
#
#        final_price_usd  fee_usd  vsize   ssize
# 5308             34.34     0.04    187     187
# 12710            34.34     0.04    187     187
# 538              34.50     0.04    188     188
# 561              34.50     0.11    188     188
# 1176             34.50     0.18    188     188
# ...                ...      ...    ...     ...
# 5300          10854.24    34.77  61398  115644
# 13011         11632.37    11.03  53154  124013
# 13250         16502.18    35.34  93500  176389
# 4399          19568.59   151.03  92959  209369
# 11387         20969.86   546.83  99577  224440
#
# [17980 rows x 5 columns]
